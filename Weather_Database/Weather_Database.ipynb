# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloudiness,
                          "Wind Speed": city_wind_speed,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | egvekinot
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | bonavista
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | moree
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | gat
# Processing Record 14 of Set 1 | plettenberg bay
# Processing Record 15 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | shimoda
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | corrales
# Processing Record 23 of Set 1 | wunsiedel
# Processing Record 24 of Set 1 | atar
# Processing Record 25 of Set 1 | dingle
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | gemena
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | karaton
# Processing Record 30 of Set 1 | kargasok
# Processing Record 31 of Set 1 | medina
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | marrakesh
# Processing Record 34 of Set 1 | guerrero negro
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | gharghoda
# Processing Record 38 of Set 1 | cairns
# Processing Record 39 of Set 1 | seoul
# Processing Record 40 of Set 1 | adre
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | nome
# Processing Record 48 of Set 1 | nouakchott
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | buala
# Processing Record 1 of Set 2 | bay city
# Processing Record 2 of Set 2 | bereda
# Processing Record 3 of Set 2 | payson
# Processing Record 4 of Set 2 | jalingo
# Processing Record 5 of Set 2 | binzhou
# Processing Record 6 of Set 2 | ternate
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 2 | tunduma
# Processing Record 10 of Set 2 | rawson
# Processing Record 11 of Set 2 | plattsburgh
# Processing Record 12 of Set 2 | beira
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 2 | khalkis
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | craig
# Processing Record 18 of Set 2 | chunskiy
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | kembe
# Processing Record 21 of Set 2 | dunedin
# Processing Record 22 of Set 2 | erzin
# Processing Record 23 of Set 2 | mogadishu
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 2 | puerto carreno
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 2 | patitirion
# Processing Record 35 of Set 2 | nouadhibou
# Processing Record 36 of Set 2 | xai-xai
# Processing Record 37 of Set 2 | seymchan
# Processing Record 38 of Set 2 | manzil salim
# Processing Record 39 of Set 2 | ust-koksa
# Processing Record 40 of Set 2 | yulara
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | leningradskiy
# Processing Record 45 of Set 2 | besikduzu
# Processing Record 46 of Set 2 | el silencio
# Processing Record 47 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 2 | vagur
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | souillac
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | pangnirtung
# Processing Record 3 of Set 3 | grindavik
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | nancha
# Processing Record 6 of Set 3 | carutapera
# Processing Record 7 of Set 3 | coahuayana
# Processing Record 8 of Set 3 | turukhansk
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | rondonopolis
# Processing Record 11 of Set 3 | iquitos
# Processing Record 12 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | tabukiniberu
# City not found. Skipping...
# Processing Record 15 of Set 3 | sao filipe
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | lima
# Processing Record 18 of Set 3 | cacu
# Processing Record 19 of Set 3 | baruun-urt
# Processing Record 20 of Set 3 | gabu
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | lagoa
# Processing Record 24 of Set 3 | haines junction
# Processing Record 25 of Set 3 | taoudenni
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | kahului
# Processing Record 29 of Set 3 | goma
# Processing Record 30 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | cabrero
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | skjervoy
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | tocopilla
# Processing Record 37 of Set 3 | bathsheba
# Processing Record 38 of Set 3 | leshukonskoye
# Processing Record 39 of Set 3 | ketchikan
# Processing Record 40 of Set 3 | aku
# Processing Record 41 of Set 3 | kununurra
# Processing Record 42 of Set 3 | skagen
# Processing Record 43 of Set 3 | bluff
# Processing Record 44 of Set 3 | havoysund
# Processing Record 45 of Set 3 | dubbo
# Processing Record 46 of Set 3 | kaka
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | waingapu
# Processing Record 49 of Set 3 | qaanaaq
# Processing Record 50 of Set 3 | ornskoldsvik
# Processing Record 1 of Set 4 | vardo
# Processing Record 2 of Set 4 | viedma
# Processing Record 3 of Set 4 | clyde river
# Processing Record 4 of Set 4 | moron
# Processing Record 5 of Set 4 | porbandar
# Processing Record 6 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 4 | zyryanka
# Processing Record 8 of Set 4 | alofi
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | mount isa
# Processing Record 11 of Set 4 | constitucion
# Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | teya
# Processing Record 15 of Set 4 | hambantota
# Processing Record 16 of Set 4 | moose factory
# Processing Record 17 of Set 4 | necochea
# Processing Record 18 of Set 4 | cadillac
# Processing Record 19 of Set 4 | tazovskiy
# Processing Record 20 of Set 4 | santa cruz de tenerife
# Processing Record 21 of Set 4 | cotija
# City not found. Skipping...
# Processing Record 22 of Set 4 | half moon bay
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 4 | mizdah
# Processing Record 26 of Set 4 | kruisfontein
# Processing Record 27 of Set 4 | namatanai
# Processing Record 28 of Set 4 | bilibino
# Processing Record 29 of Set 4 | tiznit
# Processing Record 30 of Set 4 | kysyl-syr
# Processing Record 31 of Set 4 | prieska
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | isangel
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | katsuura
# Processing Record 36 of Set 4 | biskupiec
# Processing Record 37 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 4 | luzhou
# Processing Record 39 of Set 4 | norman wells
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | la ronge
# Processing Record 42 of Set 4 | morros
# Processing Record 43 of Set 4 | divnogorsk
# Processing Record 44 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 4 | kavieng
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | cayenne
# Processing Record 48 of Set 4 | new bedford
# Processing Record 49 of Set 4 | north bend
# Processing Record 50 of Set 4 | fare
# Processing Record 1 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | suamico
# Processing Record 4 of Set 5 | tlanisco
# City not found. Skipping...
# Processing Record 5 of Set 5 | thinadhoo
# Processing Record 6 of Set 5 | kerema
# Processing Record 7 of Set 5 | byron bay
# Processing Record 8 of Set 5 | blois
# Processing Record 9 of Set 5 | nhulunbuy
# Processing Record 10 of Set 5 | ribeira grande
# Processing Record 11 of Set 5 | trairi
# Processing Record 12 of Set 5 | bontang
# Processing Record 13 of Set 5 | binga
# Processing Record 14 of Set 5 | hervey bay
# Processing Record 15 of Set 5 | ahipara
# Processing Record 16 of Set 5 | salym
# Processing Record 17 of Set 5 | barrow
# Processing Record 18 of Set 5 | sarankhola
# Processing Record 19 of Set 5 | itarema
# Processing Record 20 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 21 of Set 5 | balboa
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | sovetskiy
# Processing Record 24 of Set 5 | kaeo
# Processing Record 25 of Set 5 | marshall
# Processing Record 26 of Set 5 | bandarbeyla
# Processing Record 27 of Set 5 | vao
# Processing Record 28 of Set 5 | lompoc
# Processing Record 29 of Set 5 | aklavik
# Processing Record 30 of Set 5 | homer
# Processing Record 31 of Set 5 | san cristobal
# Processing Record 32 of Set 5 | mount gambier
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | yichun
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | high level
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | taguatinga
# Processing Record 39 of Set 5 | nanortalik
# Processing Record 40 of Set 5 | gafanha da encarnacao
# Processing Record 41 of Set 5 | komsomolskiy
# Processing Record 42 of Set 5 | kuryk
# Processing Record 43 of Set 5 | yar-sale
# Processing Record 44 of Set 5 | goba
# Processing Record 45 of Set 5 | ilhabela
# Processing Record 46 of Set 5 | zenzeli
# Processing Record 47 of Set 5 | la malbaie
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | naze
# Processing Record 50 of Set 5 | chicama
# Processing Record 1 of Set 6 | shenjiamen
# Processing Record 2 of Set 6 | port-cartier
# Processing Record 3 of Set 6 | bengkulu
# Processing Record 4 of Set 6 | kyshtovka
# Processing Record 5 of Set 6 | pouebo
# Processing Record 6 of Set 6 | pop
# Processing Record 7 of Set 6 | jizan
# Processing Record 8 of Set 6 | prabumulih
# Processing Record 9 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 10 of Set 6 | tilichiki
# Processing Record 11 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 6 | brokopondo
# Processing Record 13 of Set 6 | port elizabeth
# Processing Record 14 of Set 6 | el prat de llobregat
# Processing Record 15 of Set 6 | labuhan
# Processing Record 16 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 6 | ugoofaaru
# Processing Record 18 of Set 6 | lethem
# Processing Record 19 of Set 6 | stribro
# Processing Record 20 of Set 6 | najran
# Processing Record 21 of Set 6 | talnakh
# Processing Record 22 of Set 6 | chokurdakh
# Processing Record 23 of Set 6 | khasan
# Processing Record 24 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 6 | kuusamo
# Processing Record 26 of Set 6 | ati
# Processing Record 27 of Set 6 | krasnoselkup
# Processing Record 28 of Set 6 | taltal
# Processing Record 29 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 30 of Set 6 | qaqortoq
# Processing Record 31 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | beringovskiy
# Processing Record 34 of Set 6 | san juan
# Processing Record 35 of Set 6 | tessaoua
# Processing Record 36 of Set 6 | middelburg
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 6 | kasongo-lunda
# Processing Record 41 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | anadyr
# Processing Record 44 of Set 6 | saint-joseph
# Processing Record 45 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 6 | manaus
# Processing Record 47 of Set 6 | ambon
# Processing Record 48 of Set 6 | keskin
# Processing Record 49 of Set 6 | nizhnevartovsk
# Processing Record 50 of Set 6 | geraldton
# Processing Record 1 of Set 7 | moerai
# Processing Record 2 of Set 7 | norsup
# Processing Record 3 of Set 7 | cidreira
# Processing Record 4 of Set 7 | padang
# Processing Record 5 of Set 7 | floro
# Processing Record 6 of Set 7 | samana
# Processing Record 7 of Set 7 | jijiga
# Processing Record 8 of Set 7 | mayo
# Processing Record 9 of Set 7 | novyy urengoy
# Processing Record 10 of Set 7 | lebanon
# Processing Record 11 of Set 7 | bo rai
# Processing Record 12 of Set 7 | saint george
# Processing Record 13 of Set 7 | saint-pierre
# Processing Record 14 of Set 7 | wagar
# Processing Record 15 of Set 7 | alihe
# Processing Record 16 of Set 7 | hualmay
# Processing Record 17 of Set 7 | ambilobe
# Processing Record 18 of Set 7 | cap malheureux
# Processing Record 19 of Set 7 | mecca
# Processing Record 20 of Set 7 | santiago
# Processing Record 21 of Set 7 | berezovka
# Processing Record 22 of Set 7 | laguna
# Processing Record 23 of Set 7 | lavrentiya
# Processing Record 24 of Set 7 | sitka
# Processing Record 25 of Set 7 | arraial do cabo
# Processing Record 26 of Set 7 | altea
# Processing Record 27 of Set 7 | vanimo
# Processing Record 28 of Set 7 | muros
# Processing Record 29 of Set 7 | kaseda
# Processing Record 30 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 7 | college
# Processing Record 32 of Set 7 | dombarovskiy
# Processing Record 33 of Set 7 | dryden
# Processing Record 34 of Set 7 | bulgan
# Processing Record 35 of Set 7 | aginskoye
# Processing Record 36 of Set 7 | shahreza
# Processing Record 37 of Set 7 | idlib
# Processing Record 38 of Set 7 | ganta
# Processing Record 39 of Set 7 | praya
# Processing Record 40 of Set 7 | ilulissat
# Processing Record 41 of Set 7 | comodoro rivadavia
# Processing Record 42 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 43 of Set 7 | buin
# Processing Record 44 of Set 7 | sabha
# Processing Record 45 of Set 7 | makakilo city
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | iqaluit
# Processing Record 48 of Set 7 | kharagpur
# Processing Record 49 of Set 7 | tual
# Processing Record 50 of Set 7 | ulaanbaatar
# Processing Record 1 of Set 8 | gorontalo
# Processing Record 2 of Set 8 | bardiyah
# Processing Record 3 of Set 8 | mashhad
# Processing Record 4 of Set 8 | anstruther
# Processing Record 5 of Set 8 | fairfield
# Processing Record 6 of Set 8 | bulungu
# Processing Record 7 of Set 8 | yamada
# Processing Record 8 of Set 8 | kisangani
# Processing Record 9 of Set 8 | beian
# Processing Record 10 of Set 8 | skovorodino
# Processing Record 11 of Set 8 | upata
# Processing Record 12 of Set 8 | bhanvad
# Processing Record 13 of Set 8 | tuatapere
# Processing Record 14 of Set 8 | jacksonville beach
# Processing Record 15 of Set 8 | suleja
# Processing Record 16 of Set 8 | lulea
# Processing Record 17 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 18 of Set 8 | iralaya
# Processing Record 19 of Set 8 | gao
# Processing Record 20 of Set 8 | ancud
# Processing Record 21 of Set 8 | kantang
# Processing Record 22 of Set 8 | zhuhai
# Processing Record 23 of Set 8 | guarapari
# Processing Record 24 of Set 8 | kamaishi
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | mao
# Processing Record 27 of Set 8 | hauge
# Processing Record 28 of Set 8 | katakwi
# Processing Record 29 of Set 8 | puri
# Processing Record 30 of Set 8 | ampanihy
# Processing Record 31 of Set 8 | sieut
# Processing Record 32 of Set 8 | cururupu
# Processing Record 33 of Set 8 | akdepe
# Processing Record 34 of Set 8 | tulun
# Processing Record 35 of Set 8 | burica
# City not found. Skipping...
# Processing Record 36 of Set 8 | aitape
# Processing Record 37 of Set 8 | katangli
# Processing Record 38 of Set 8 | flin flon
# Processing Record 39 of Set 8 | trelew
# Processing Record 40 of Set 8 | honiara
# Processing Record 41 of Set 8 | kagadi
# Processing Record 42 of Set 8 | te anau
# Processing Record 43 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 8 | aquiraz
# Processing Record 45 of Set 8 | mazamari
# Processing Record 46 of Set 8 | hopelchen
# Processing Record 47 of Set 8 | gimli
# Processing Record 48 of Set 8 | gokak
# Processing Record 49 of Set 8 | broken hill
# Processing Record 50 of Set 8 | poum
# Processing Record 1 of Set 9 | qui nhon
# Processing Record 2 of Set 9 | porto novo
# Processing Record 3 of Set 9 | kirillov
# Processing Record 4 of Set 9 | eenhana
# Processing Record 5 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 9 | camargo
# Processing Record 7 of Set 9 | camacha
# Processing Record 8 of Set 9 | aswan
# Processing Record 9 of Set 9 | tessalit
# Processing Record 10 of Set 9 | bubaque
# Processing Record 11 of Set 9 | petukhovo
# Processing Record 12 of Set 9 | oktyabrskoye
# Processing Record 13 of Set 9 | port blair
# Processing Record 14 of Set 9 | ponta do sol
# Processing Record 15 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 9 | ozernovskiy
# Processing Record 17 of Set 9 | kolpashevo
# Processing Record 18 of Set 9 | tabou
# Processing Record 19 of Set 9 | mantua
# Processing Record 20 of Set 9 | shingu
# Processing Record 21 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 9 | alice springs
# Processing Record 23 of Set 9 | poli
# Processing Record 24 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 9 | acajutla
# Processing Record 26 of Set 9 | salinopolis
# Processing Record 27 of Set 9 | clarence town
# Processing Record 28 of Set 9 | katobu
# Processing Record 29 of Set 9 | chifeng
# Processing Record 30 of Set 9 | jiangyou
# Processing Record 31 of Set 9 | porto de moz
# Processing Record 32 of Set 9 | san patricio
# Processing Record 33 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 34 of Set 9 | east london
# Processing Record 35 of Set 9 | cuamba
# Processing Record 36 of Set 9 | bang saphan
# Processing Record 37 of Set 9 | juneau
# Processing Record 38 of Set 9 | launceston
# Processing Record 39 of Set 9 | hobyo
# Processing Record 40 of Set 9 | riyadh
# Processing Record 41 of Set 9 | neiafu
# Processing Record 42 of Set 9 | newport
# Processing Record 43 of Set 9 | dvinskoy
# Processing Record 44 of Set 9 | mirnyy
# Processing Record 45 of Set 9 | los llanos de aridane
# Processing Record 46 of Set 9 | kaya
# Processing Record 47 of Set 9 | tautira
# Processing Record 48 of Set 9 | jumla
# Processing Record 49 of Set 9 | acari
# Processing Record 50 of Set 9 | sawankhalok
# Processing Record 1 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 2 of Set 10 | tyup
# Processing Record 3 of Set 10 | kosum phisai
# Processing Record 4 of Set 10 | zhanaozen
# Processing Record 5 of Set 10 | luis gil perez
# Processing Record 6 of Set 10 | deputatskiy
# Processing Record 7 of Set 10 | nassau
# Processing Record 8 of Set 10 | puerto escondido
# Processing Record 9 of Set 10 | quatre cocos
# Processing Record 10 of Set 10 | sandwick
# Processing Record 11 of Set 10 | fairbanks
# Processing Record 12 of Set 10 | qidong
# Processing Record 13 of Set 10 | bambous virieux
# Processing Record 14 of Set 10 | bon accord
# Processing Record 15 of Set 10 | nemuro
# Processing Record 16 of Set 10 | namibe
# Processing Record 17 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 10 | santa maria
# Processing Record 19 of Set 10 | laksar
# Processing Record 20 of Set 10 | guiglo
# Processing Record 21 of Set 10 | borujan
# City not found. Skipping...
# Processing Record 22 of Set 10 | wanning
# Processing Record 23 of Set 10 | villa carlos paz
# Processing Record 24 of Set 10 | sibolga
# Processing Record 25 of Set 10 | ayagoz
# Processing Record 26 of Set 10 | kenora
# Processing Record 27 of Set 10 | tibiri
# Processing Record 28 of Set 10 | kilbirnie
# Processing Record 29 of Set 10 | dongsheng
# Processing Record 30 of Set 10 | akureyri
# Processing Record 31 of Set 10 | milkovo
# Processing Record 32 of Set 10 | luderitz
# Processing Record 33 of Set 10 | kropotkin
# Processing Record 34 of Set 10 | kastamonu
# Processing Record 35 of Set 10 | iquique
# Processing Record 36 of Set 10 | zhangye
# Processing Record 37 of Set 10 | praia
# Processing Record 38 of Set 10 | ponta delgada
# Processing Record 39 of Set 10 | bam
# Processing Record 40 of Set 10 | saint-louis
# Processing Record 41 of Set 10 | taman
# Processing Record 42 of Set 10 | aloleng
# Processing Record 43 of Set 10 | greenfield
# Processing Record 44 of Set 10 | tyukhtet
# Processing Record 45 of Set 10 | jalu
# Processing Record 46 of Set 10 | yantal
# Processing Record 47 of Set 10 | roald
# Processing Record 48 of Set 10 | brae
# Processing Record 49 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 10 | filadelfia
# Processing Record 1 of Set 11 | port hedland
# Processing Record 2 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 11 | freeport
# Processing Record 4 of Set 11 | orange walk
# Processing Record 5 of Set 11 | vadso
# Processing Record 6 of Set 11 | lata
# Processing Record 7 of Set 11 | oktyabrskiy
# Processing Record 8 of Set 11 | thohoyandou
# Processing Record 9 of Set 11 | havre
# Processing Record 10 of Set 11 | buta
# Processing Record 11 of Set 11 | saint-augustin
# Processing Record 12 of Set 11 | ostrovnoy
# Processing Record 13 of Set 11 | doha
# Processing Record 14 of Set 11 | lorengau
# Processing Record 15 of Set 11 | tarauaca
# Processing Record 16 of Set 11 | tikhvin
# Processing Record 17 of Set 11 | tarko-sale
# Processing Record 18 of Set 11 | tefe
# Processing Record 19 of Set 11 | marzuq
# Processing Record 20 of Set 11 | makushino
# Processing Record 21 of Set 11 | koungou
# Processing Record 22 of Set 11 | acapulco
# Processing Record 23 of Set 11 | harper
# Processing Record 24 of Set 11 | pafos
# Processing Record 25 of Set 11 | bambanglipuro
# Processing Record 26 of Set 11 | lokoja
# Processing Record 27 of Set 11 | pontianak
# Processing Record 28 of Set 11 | adeje
# Processing Record 29 of Set 11 | virden
# Processing Record 30 of Set 11 | amalapuram
# Processing Record 31 of Set 11 | nuuk
# Processing Record 32 of Set 11 | hofn
# Processing Record 33 of Set 11 | mackay
# Processing Record 34 of Set 11 | uruguaiana
# Processing Record 35 of Set 11 | asau
# Processing Record 36 of Set 11 | rio verde de mato grosso
# Processing Record 37 of Set 11 | morehead
# Processing Record 38 of Set 11 | rajapur
# Processing Record 39 of Set 11 | huilong
# Processing Record 40 of Set 11 | fort nelson
# Processing Record 41 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 11 | povenets
# Processing Record 43 of Set 11 | rocha
# Processing Record 44 of Set 11 | port hardy
# Processing Record 45 of Set 11 | marsh harbour
# Processing Record 46 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 47 of Set 11 | inhambane
# Processing Record 48 of Set 11 | orocue
# Processing Record 49 of Set 11 | le port
# Processing Record 50 of Set 11 | north platte
# Processing Record 1 of Set 12 | paraiso
# Processing Record 2 of Set 12 | revda
# Processing Record 3 of Set 12 | coruripe
# Processing Record 4 of Set 12 | puerto colombia
# Processing Record 5 of Set 12 | xinmin
# Processing Record 6 of Set 12 | santa barbara
# Processing Record 7 of Set 12 | sao joao da barra
# Processing Record 8 of Set 12 | aykhal
# Processing Record 9 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 12 | krapina
# Processing Record 11 of Set 12 | conceicao do araguaia
# Processing Record 12 of Set 12 | varkaus
# Processing Record 13 of Set 12 | prainha
# Processing Record 14 of Set 12 | khuzdar
# Processing Record 15 of Set 12 | hovd
# Processing Record 16 of Set 12 | general roca
# Processing Record 17 of Set 12 | lasa
# Processing Record 18 of Set 12 | aksu
# Processing Record 19 of Set 12 | praia da vitoria
# Processing Record 20 of Set 12 | itoman
# Processing Record 21 of Set 12 | merrill
# Processing Record 22 of Set 12 | mareeba
# Processing Record 23 of Set 12 | haftoni
# Processing Record 24 of Set 12 | qandala
# Processing Record 25 of Set 12 | port macquarie
# Processing Record 26 of Set 12 | lesnoy
# Processing Record 27 of Set 12 | teguise
# Processing Record 28 of Set 12 | paka
# Processing Record 29 of Set 12 | adrar
# Processing Record 30 of Set 12 | cabinda
# Processing Record 31 of Set 12 | mokhsogollokh
# Processing Record 32 of Set 12 | broome
# Processing Record 33 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 34 of Set 12 | ulladulla
# Processing Record 35 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 36 of Set 12 | black river
# Processing Record 37 of Set 12 | veraval
# Processing Record 38 of Set 12 | alfeld
# Processing Record 39 of Set 12 | zuenoula
# Processing Record 40 of Set 12 | piacabucu
# Processing Record 41 of Set 12 | letka
# Processing Record 42 of Set 12 | springbok
# Processing Record 43 of Set 12 | turochak
# Processing Record 44 of Set 12 | saiki
# Processing Record 45 of Set 12 | khandbari
# Processing Record 46 of Set 12 | butembo
# Processing Record 47 of Set 12 | orlik
# Processing Record 48 of Set 12 | port lincoln
# Processing Record 49 of Set 12 | meridian
# Processing Record 50 of Set 12 | pimentel
# Processing Record 1 of Set 13 | zugdidi
# Processing Record 2 of Set 13 | penzance
# Processing Record 3 of Set 13 | sakakah
# Processing Record 4 of Set 13 | tunceli
# Processing Record 5 of Set 13 | ardesen
# Processing Record 6 of Set 13 | tiarei
# Processing Record 7 of Set 13 | pacific grove
# Processing Record 8 of Set 13 | hailey
# Processing Record 9 of Set 13 | mangan
# Processing Record 10 of Set 13 | rioja
# Processing Record 11 of Set 13 | esna
# Processing Record 12 of Set 13 | kavant
# City not found. Skipping...
# Processing Record 13 of Set 13 | waipawa
# Processing Record 14 of Set 13 | senneterre
# Processing Record 15 of Set 13 | biak
# Processing Record 16 of Set 13 | santa marta
# Processing Record 17 of Set 13 | glotovka
# Processing Record 18 of Set 13 | eirunepe
# Processing Record 19 of Set 13 | bairiki
# Processing Record 20 of Set 13 | chernyshevskiy
# Processing Record 21 of Set 13 | baft
# Processing Record 22 of Set 13 | ginda
# Processing Record 23 of Set 13 | sisimiut
# Processing Record 24 of Set 13 | belyy yar
# Processing Record 25 of Set 13 | khor
# Processing Record 26 of Set 13 | yanam
# Processing Record 27 of Set 13 | ribeira brava
# Processing Record 28 of Set 13 | mamonovo
# Processing Record 29 of Set 13 | wewak
# Processing Record 30 of Set 13 | pombas
# Processing Record 31 of Set 13 | vostok
# Processing Record 32 of Set 13 | ixtapa
# Processing Record 33 of Set 13 | nokaneng
# Processing Record 34 of Set 13 | bondowoso
# Processing Record 35 of Set 13 | ahuimanu
# Processing Record 36 of Set 13 | saint anthony
# Processing Record 37 of Set 13 | sonipat
# Processing Record 38 of Set 13 | ivanava
# Processing Record 39 of Set 13 | mgandu
# Processing Record 40 of Set 13 | winnemucca
# Processing Record 41 of Set 13 | emba
# Processing Record 42 of Set 13 | meulaboh
# Processing Record 43 of Set 13 | awjilah
# Processing Record 44 of Set 13 | svetlaya
# Processing Record 45 of Set 13 | hay river
# Processing Record 46 of Set 13 | kidal
# Processing Record 47 of Set 13 | chumikan
# Processing Record 48 of Set 13 | auki
# Processing Record 49 of Set 13 | vila velha
# Processing Record 50 of Set 13 | maceio
# Processing Record 1 of Set 14 | coldingham
# Processing Record 2 of Set 14 | grenada
# Processing Record 3 of Set 14 | santa ines
# Processing Record 4 of Set 14 | sioux lookout
# Processing Record 5 of Set 14 | jurm
# Processing Record 6 of Set 14 | marathon
# Processing Record 7 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 8 of Set 14 | plaster rock
# Processing Record 9 of Set 14 | horizontina
# Processing Record 10 of Set 14 | saint-georges
# Processing Record 11 of Set 14 | horasan
# Processing Record 12 of Set 14 | altay
# Processing Record 13 of Set 14 | mormugao
# Processing Record 14 of Set 14 | gunjur
# Processing Record 15 of Set 14 | trincomalee
# Processing Record 16 of Set 14 | grants
# Processing Record 17 of Set 14 | kushiro
# Processing Record 18 of Set 14 | the valley
# Processing Record 19 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 14 | liverpool
# Processing Record 21 of Set 14 | virginia beach
# Processing Record 22 of Set 14 | priekule
# Processing Record 23 of Set 14 | barabinsk
# Processing Record 24 of Set 14 | belaya gora
# Processing Record 25 of Set 14 | daru
# Processing Record 26 of Set 14 | madinat sittah uktubar
# Processing Record 27 of Set 14 | santa rosa
# Processing Record 28 of Set 14 | nioki
# Processing Record 29 of Set 14 | sibundoy
# Processing Record 30 of Set 14 | mezhova
# Processing Record 31 of Set 14 | mabilo
# City not found. Skipping...
# Processing Record 32 of Set 14 | antalaha
# Processing Record 33 of Set 14 | litovko
# Processing Record 34 of Set 14 | severo-kurilsk
# Processing Record 35 of Set 14 | hirara
# Processing Record 36 of Set 14 | ca mau
# Processing Record 37 of Set 14 | ligayan
# Processing Record 38 of Set 14 | pochutla
# Processing Record 39 of Set 14 | xuddur
# Processing Record 40 of Set 14 | klaksvik
# Processing Record 41 of Set 14 | howard
# Processing Record 42 of Set 14 | buraydah
# Processing Record 43 of Set 14 | kamenka
# Processing Record 44 of Set 14 | irbit
# Processing Record 45 of Set 14 | bismarck
# Processing Record 46 of Set 14 | suslovo
# Processing Record 47 of Set 14 | mae hong son
# Processing Record 48 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 49 of Set 14 | banda aceh
# Processing Record 50 of Set 14 | quelimane
# Processing Record 1 of Set 15 | vila
# Processing Record 2 of Set 15 | sola
# Processing Record 3 of Set 15 | tepeji
# City not found. Skipping...
# Processing Record 4 of Set 15 | alyangula
# Processing Record 5 of Set 15 | yian
# City not found. Skipping...
# Processing Record 6 of Set 15 | hamilton
# Processing Record 7 of Set 15 | stettler
# Processing Record 8 of Set 15 | churapcha
# Processing Record 9 of Set 15 | kushima
# Processing Record 10 of Set 15 | kumbo
# Processing Record 11 of Set 15 | redwater
# Processing Record 12 of Set 15 | urubicha
# Processing Record 13 of Set 15 | dogondoutchi
# Processing Record 14 of Set 15 | kiama
# Processing Record 15 of Set 15 | sorong
# Processing Record 16 of Set 15 | husavik
# Processing Record 17 of Set 15 | caudry
# Processing Record 18 of Set 15 | gotsu
# Processing Record 19 of Set 15 | orange cove
# Processing Record 20 of Set 15 | baykit
# Processing Record 21 of Set 15 | lusambo
# Processing Record 22 of Set 15 | hami
# Processing Record 23 of Set 15 | alibag
# Processing Record 24 of Set 15 | port moresby
# Processing Record 25 of Set 15 | omsukchan
# Processing Record 26 of Set 15 | teknaf
# Processing Record 27 of Set 15 | de-kastri
# Processing Record 28 of Set 15 | lakes entrance
# Processing Record 29 of Set 15 | gazanjyk
# Processing Record 30 of Set 15 | harwich
# Processing Record 31 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 15 | abha
# Processing Record 33 of Set 15 | togur
# Processing Record 34 of Set 15 | insch
# Processing Record 35 of Set 15 | raudeberg
# Processing Record 36 of Set 15 | sungaipenuh
# Processing Record 37 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 15 | duluth
# Processing Record 39 of Set 15 | kathmandu
# Processing Record 40 of Set 15 | tramore
# Processing Record 41 of Set 15 | visnes
# Processing Record 42 of Set 15 | sorland
# Processing Record 43 of Set 15 | zemio
# Processing Record 44 of Set 15 | bela vista
# Processing Record 45 of Set 15 | tsabong
# Processing Record 46 of Set 15 | xichang
# Processing Record 47 of Set 15 | chimore
# Processing Record 48 of Set 15 | la baneza
# Processing Record 49 of Set 15 | wuda
# Processing Record 50 of Set 15 | hede
# Processing Record 1 of Set 16 | campoverde
# Processing Record 2 of Set 16 | chipinge
# Processing Record 3 of Set 16 | ulaangom
# Processing Record 4 of Set 16 | prince rupert
# Processing Record 5 of Set 16 | nanakuli
# Processing Record 6 of Set 16 | walvis bay
# Processing Record 7 of Set 16 | goure
# Processing Record 8 of Set 16 | storslett
# Processing Record 9 of Set 16 | pelym
# Processing Record 10 of Set 16 | jieshi
# Processing Record 11 of Set 16 | bodden town
# Processing Record 12 of Set 16 | henties bay
# Processing Record 13 of Set 16 | nizhniy tsasuchey
# Processing Record 14 of Set 16 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 16 | puerto penasco
# Processing Record 16 of Set 16 | barra da estiva
# Processing Record 17 of Set 16 | domoni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 703

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     60.91        48          40
# 1     Egvekinot      RU  66.3167 -179.1667     12.34        97         100
# 2      Saldanha      ZA -33.0117   17.9442     71.65        71          50
# 3     Upernavik      GL  72.7868  -56.1549     -1.59        92         100
# 4      Cherskiy      RU  68.7500  161.3000    -19.68        95         100
# 5     Bonavista      CA  48.6499  -53.1147     25.97        60          40
# 6       Ushuaia      AR -54.8000  -68.3000     58.66        47          20
# 7         Moree      AU -29.4667  149.8500     78.57        52           4
# 8        Atuona      PF  -9.8000 -139.0333     78.71        79          97
# 9   Port Alfred      ZA -33.5906   26.8910     68.18        90          39
#
#    Wind Speed Current Description
# 0       36.82    scattered clouds
# 1        2.17          light snow
# 2       33.80    scattered clouds
# 3        2.84     overcast clouds
# 4        1.23     overcast clouds
# 5        3.38    scattered clouds
# 6       26.46          few clouds
# 7       13.56           clear sky
# 8       20.42     overcast clouds
# 9        5.01          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"
column_list = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_reordered_df = city_data_df[column_list]

# Display sample data
city_data_reordered_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     60.91        48          40
# 1     Egvekinot      RU  66.3167 -179.1667     12.34        97         100
# 2      Saldanha      ZA -33.0117   17.9442     71.65        71          50
# 3     Upernavik      GL  72.7868  -56.1549     -1.59        92         100
# 4      Cherskiy      RU  68.7500  161.3000    -19.68        95         100
#
#    Wind Speed Current Description
# 0       36.82    scattered clouds
# 1        2.17          light snow
# 2       33.80    scattered clouds
# 3        2.84     overcast clouds
# 4        1.23     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_reordered_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_reordered_df.to_csv(output_file, index_label="City_ID")
